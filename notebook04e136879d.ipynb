# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('../input/insurance/insurance.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df['charges'] = df['charges'].astype(int)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region  charges
# 0   19  female  27.900         0    yes  southwest    16884
# 1   18    male  33.770         1     no  southeast     1725
# 2   28    male  33.000         3     no  southeast     4449
# 3   33    male  22.705         0     no  northwest    21984
# 4   32    male  28.880         0     no  northwest     3866

# %%
df['charges'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["dummy"] = 5

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region  charges  dummy
# 0   19  female  27.900         0    yes  southwest    16884      5
# 1   18    male  33.770         1     no  southeast     1725      5
# 2   28    male  33.000         3     no  southeast     4449      5
# 3   33    male  22.705         0     no  northwest    21984      5
# 4   32    male  28.880         0     no  northwest     3866      5

# %%
df.drop('dummy', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region  charges
# 0   19  female  27.900         0    yes  southwest    16884
# 1   18    male  33.770         1     no  southeast     1725
# 2   28    male  33.000         3     no  southeast     4449
# 3   33    male  22.705         0     no  northwest    21984
# 4   32    male  28.880         0     no  northwest     3866

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region  charges
# 0   19  female  27.900         0    yes  southwest    16884
# 1   18    male  33.770         1     no  southeast     1725
# 2   28    male  33.000         3     no  southeast     4449
# 3   33    male  22.705         0     no  northwest    21984
# 4   32    male  28.880         0     no  northwest     3866

# %%
df["sex"] = 'female'

# %%
df_female = df[df["sex"] == 'female']

# %%
df_female
# Out:
#       age     sex     bmi  children smoker     region  charges
# 0      19  female  27.900         0    yes  southwest    16884
# 1      18  female  33.770         1     no  southeast     1725
# 2      28  female  33.000         3     no  southeast     4449
# 3      33  female  22.705         0     no  northwest    21984
# 4      32  female  28.880         0     no  northwest     3866
# ...   ...     ...     ...       ...    ...        ...      ...
# 1333   50  female  30.970         3     no  northwest    10600
# 1334   18  female  31.920         0     no  northeast     2205
# 1335   18  female  36.850         0     no  southeast     1629
# 1336   21  female  25.800         0     no  southwest     2007
# 1337   61  female  29.070         0    yes  northwest    29141
#
# [1338 rows x 7 columns]
